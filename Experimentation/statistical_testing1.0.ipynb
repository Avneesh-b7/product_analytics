# %%
#  dow load the data from kaggle


# from pathlib import Path

# # Requires ~/.kaggle/kaggle.json (API token) to be set up first.
# # Downloads directly into a local data/ folder alongside this notebook.
# data_dir = Path("data/sales-and-satisfaction")
# data_dir.mkdir(parents=True, exist_ok=True)

# !kaggle datasets download -d matinmahmoudi/sales-and-satisfaction -p "{data_dir}" --unzip

# list(data_dir.iterdir())
